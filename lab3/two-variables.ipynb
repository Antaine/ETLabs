# %% [markdown]
# # Two Variables
#  https://matplotlib.org/3.1.1/tutorials/introductory/pyplot.html

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('Numbers')
# Out:
# Text(0, 0.5, 'Numbers')

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'r')

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'bx')

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'bo')

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'b:')

# %%
x = np.linspace(0.0, 100.0, 101)
y = 2.0 * x

plt.plot(x,y,'k.')

# %% [markdown]
# $$y = 2 x $$

# %%
x = np.linspace(0.0, 100.0, 10)
y = 2.0 * x

plt.plot(x,y,'k.')

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'b-')

# %%
x = np.linspace(0.0, 100.0, 10)
y = -2.0 * x

plt.plot(x,y,'k')

# %%
x = np.linspace(0.0, 100.0, 10)
y = x * x

plt.plot(x,y,'r')

# %%
x = np.linspace(0.0, 100.0, 10)
y = x * x * x

plt.plot(x,y,'b')

# %%
x = np.linspace(0.0, 100.0, 10)
y1 = x * x
y2 = x * x * x


plt.plot(x,y1,'r')
plt.plot(x,y2,'b')

# %%
x = np.linspace(0.0, 100.0, 10)
y = x * x

plt.plot(x,y,'r')

# %%
x = np.linspace(0.0, 100.0, 10)
y1 = x * x * x
y2 = x * x * x * x

plt.plot(x,y1,'b')
plt.plot(x,y2,'r')

# %%
x = np.linspace(0.0, 100.0, 11)
y1 = 2.0 * x + 5.0
y2 = 1.0 * x + 5.0
y3 = -2.0 * x + 0.0

plt.plot(x,y1,'r')
plt.plot(x,y2,'g')
plt.plot(x,y3,'b')

# %%
x = np.linspace(0.0, 100.0, 1001)
y1 = np.exp(x)
y2 = 1.0 / np.exp(x)
y3 = x**x

plt.plot(x,y1,'r')x = np.linspace(0.0, 100.0, 1001)
y1 = np.exp(x)
y2 = 1.0 / np.exp(x)
y3 = x**x

plt.plot(x,y1,'r')
#plt.plot(x,y2,'g')
#plt.plot(x,y3,'b')

# %%
x = np.linspace(0.0, 100.0, 1001)
y1 = np.exp(x)
y2 = 1.0 / np.exp(x)
y3 = x**x


plt.plot(x,y2,'g')

# %%
x = np.linspace(0.0, 100.0, 1001)
y1 = np.exp(x)
y2 = 1.0 / np.exp(x)
y3 = x**x

plt.plot(x,y3,'b')

# %%
x = np.linspace(-100.0, 100.0, 1001)
y = x * x - 4.0 * x + 4.0


plt.plot(x,y,'g')
#plt.plot(x,y3,'b')
